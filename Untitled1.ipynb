# %%
import tensorflow as tf
import os

# %%
data_dir = '../Image_masking/carvana-image-masking-challenge'

# %%
train_images = tf.data.Dataset.list_files(os.path.join(data_dir, 'train', '*.jpg'), shuffle = False)
train_masks = tf.data.Dataset.list_files(os.path.join(data_dir, 'pp_train_masks', '*.jpg'), shuffle = False)

valid_images = tf.data.Dataset.list_files(os.path.join(data_dir, 'validation', 'images', '*.jpg'), shuffle = False)
valid_masks = tf.data.Dataset.list_files(os.path.join(data_dir, 'validation', 'masks', '*.jpg'), shuffle = False)

# %%
parse_shape = (512,512)

def parse_train_images(filename):
    image_bytes = tf.io.read_file(filename)
    image = tf.io.decode_jpeg(image_bytes, channels=3)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size = parse_shape)
    return image

def parse_train_masks(filename):
    image_bytes = tf.io.read_file(filename)
    image = tf.io.decode_jpeg(image_bytes, channels=1)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size = parse_shape)
    return image

# %%
dataset_train_images = train_images.map(parse_train_images, num_parallel_calls=4)
dataset_train_masks = train_masks.map(parse_train_masks, num_parallel_calls=4)

dataset_valid_images = valid_images.map(parse_train_images, num_parallel_calls=4)
dataset_valid_masks = valid_masks.map(parse_train_masks, num_parallel_calls=4)

# %%
dataset_train_images, dataset_train_masks, dataset_valid_images, dataset_valid_masks
# Out:
# (<ParallelMapDataset shapes: (512, 512, 3), types: tf.float32>,
#  <ParallelMapDataset shapes: (512, 512, 1), types: tf.float32>,
#  <ParallelMapDataset shapes: (512, 512, 3), types: tf.float32>,
#  <ParallelMapDataset shapes: (512, 512, 1), types: tf.float32>)

# %%
dataset = tf.data.Dataset.zip((dataset_train_images, dataset_train_masks))
validation = tf.data.Dataset.zip((dataset_valid_images, dataset_valid_masks))

# %%
from plotting import plot_image_grid

# %%
top = [next(dataset_train_images.batch(4).__iter__()).numpy(),
       next(dataset_train_masks.batch(4).__iter__()).numpy().reshape(-1,512,512)]

fig = plot_image_grid(top, transpose=True)

# %%
top = [next(dataset_valid_images.batch(4).__iter__()).numpy(),
       next(dataset_valid_masks.batch(4).__iter__()).numpy().reshape(-1,512,512)]

fig = plot_image_grid(top, transpose=True)

# %%
batch_size = 10
num_show = 4
num_epochs = 10
image_size = [512,512]
num_channels = 3
num_classes = 2

# %%
dataset = dataset.repeat(num_show)
dataset = dataset.batch(batch_size)
dataset = dataset.prefetch(1)

# %%
validation = validation.repeat(num_show)
validation = validation.batch(batch_size)

# %%
dataset
# Out:
# <PrefetchDataset shapes: ((None, 512, 512, 3), (None, 512, 512, 1)), types: (tf.float32, tf.float32)>

# %%
validation
# Out:
# <BatchDataset shapes: ((None, 512, 512, 3), (None, 512, 512, 1)), types: (tf.float32, tf.float32)>

# %%
import tensorflow as tf
from tensorflow.keras.layers import (Conv2D, Conv2DTranspose, Lambda, Dropout, 
                                     MaxPooling2D, LeakyReLU, concatenate, BatchNormalization)

# %%
def unet_conv_block(x, filters, kernel_size=3, batch_norm=True, dropout=False,
                    name_prefix="enc_", name_suffix=0):

    name_fn = lambda layer, num: '{}{}{}-{}'.format(name_prefix, layer, name_suffix, num)

    # First convolution:
    x = Conv2D(filters, kernel_size=kernel_size, activation=None,
               kernel_initializer='he_normal', padding='same',
               name=name_fn('conv', 1))(x)
    if batch_norm:
        x = BatchNormalization(name=name_fn('bn', 1))(x)
    x = LeakyReLU(alpha=0.3, name=name_fn('act', 1))(x)
    if dropout:
        x = Dropout(0.2, name=name_fn('drop', 1))(x)

    # Second convolution:
    x = Conv2D(filters, kernel_size=kernel_size, activation=None,
               kernel_initializer='he_normal', padding='same',
               name=name_fn('conv', 2))(x)
    if batch_norm:
        x = BatchNormalization(name=name_fn('bn', 2))(x)
    x = LeakyReLU(alpha=0.3, name=name_fn('act', 2))(x)

    return x


def unet_deconv_block(x, filters, kernel_size=2, strides=2, batch_norm=True, dropout=False,
                      name_prefix="dec_", name_suffix=0):

    name_fn = lambda layer, num: '{}{}{}-{}'.format(name_prefix, layer, name_suffix, num)

    # First convolution:
    x = Conv2D(filters, kernel_size=kernel_size, activation=None,
               kernel_initializer='he_normal', padding='same',
               name=name_fn('conv', 1))(x)
    if batch_norm:
        x = BatchNormalization(name=name_fn('bn', 1))(x)
    x = LeakyReLU(alpha=0.3, name=name_fn('act', 1))(x)
    if dropout:
        x = Dropout(0.2, name=name_fn('drop', 1))(x)

    # Second (de)convolution:
    x = Conv2DTranspose(filters, kernel_size=kernel_size, strides=strides,
                        activation=None, kernel_initializer='he_normal',
                        padding='same', name=name_fn('conv', 2))(x)
    if batch_norm:
        x = BatchNormalization(name=name_fn('bn', 2))(x)
    x = LeakyReLU(alpha=0.3, name=name_fn('act', 2))(x)

    return x


# As the dimensions of our images may not be normalized/even, it is possible that after 
# downsampling and upsampling, we do not reobtain the original size (with a difference 
# of +/- 1px).
# To avoid the problems this may cause, we define a layer to slightly resize the generated
# image to the dimensions of the target one:
ResizeToSame = lambda name: Lambda(
    lambda images: tf.image.resize(images[0], tf.shape(images[1])[1:3]),
    # `images` is a tuple of 2 tensors.
    # We resize the first image tensor to the shape of the 2nd
    name=name)


def unet(x, out_channels=3, layer_depth=4, filters_orig=32, kernel_size=4,
         batch_norm=True, final_activation='sigmoid'):

    # Encoding layers:
    filters = filters_orig
    outputs_for_skip = []
    for i in range(layer_depth):
        conv_block = unet_conv_block(x, filters, kernel_size,
                                     batch_norm=batch_norm, name_suffix=i)
        outputs_for_skip.append(conv_block)

        x = MaxPooling2D(2)(conv_block)

        filters = min(filters * 2, 512)

    # Bottleneck layers:
    x = unet_conv_block(x, filters, kernel_size, name_suffix='btleneck')

    # Decoding layers:
    for i in range(layer_depth):
        filters = max(filters // 2, filters_orig)

        use_dropout = i < (layer_depth - 2)
        deconv_block = unet_deconv_block(x, filters, kernel_size,
                                         batch_norm=batch_norm,
                                         dropout=use_dropout, name_suffix=i)

        shortcut = outputs_for_skip[-(i + 1)]
        deconv_block = ResizeToSame(
            name='resize_to_same{}'.format(i))([deconv_block, shortcut])

        x = concatenate([deconv_block, shortcut], axis=-1,
                        name='dec_conc{}'.format(i))

    x = Conv2D(filters=filters, kernel_size=kernel_size, activation='relu',
               padding='same', name='dec_out1')(x)
    x = Dropout(0.3, name='drop_out1')(x)
    x = Conv2D(filters=filters, kernel_size=kernel_size, activation='relu',
               padding='same', name='dec_out2')(x)
    x = Dropout(0.3, name='drop_out2')(x)
    x = Conv2D(filters=out_channels, kernel_size=1, activation=final_activation,
               padding='same', name='dec_output')(x)

    return x

# %%
kernel_size = 4
filters_orig = 32
layer_depth = 4
use_batch_norm = batch_size > 1

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

# %%
inputs = Input(shape=(*image_size, num_channels))
outputs = unet(inputs, out_channels=num_classes,layer_depth=layer_depth,
              filters_orig=filters_orig, kernel_size=kernel_size, batch_norm=use_batch_norm,
              final_activation=None)
unet_model = Model(inputs, outputs)

# %%
unet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# enc_conv0-1 (Conv2D)            (None, 512, 512, 32) 1568        input_1[0][0]
# __________________________________________________________________________________________________
# enc_bn0-1 (BatchNormalization)  (None, 512, 512, 32) 128         enc_conv0-1[0][0]
# __________________________________________________________________________________________________
# enc_act0-1 (LeakyReLU)          (None, 512, 512, 32) 0           enc_bn0-1[0][0]
# __________________________________________________________________________________________________
# enc_conv0-2 (Conv2D)            (None, 512, 512, 32) 16416       enc_act0-1[0][0]
# __________________________________________________________________________________________________
# enc_bn0-2 (BatchNormalization)  (None, 512, 512, 32) 128         enc_conv0-2[0][0]
# __________________________________________________________________________________________________
# enc_act0-2 (LeakyReLU)          (None, 512, 512, 32) 0           enc_bn0-2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           enc_act0-2[0][0]
# __________________________________________________________________________________________________
# enc_conv1-1 (Conv2D)            (None, 256, 256, 64) 32832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# enc_bn1-1 (BatchNormalization)  (None, 256, 256, 64) 256         enc_conv1-1[0][0]
# __________________________________________________________________________________________________
# enc_act1-1 (LeakyReLU)          (None, 256, 256, 64) 0           enc_bn1-1[0][0]
# __________________________________________________________________________________________________
# enc_conv1-2 (Conv2D)            (None, 256, 256, 64) 65600       enc_act1-1[0][0]
# __________________________________________________________________________________________________
# enc_bn1-2 (BatchNormalization)  (None, 256, 256, 64) 256         enc_conv1-2[0][0]
# __________________________________________________________________________________________________
# enc_act1-2 (LeakyReLU)          (None, 256, 256, 64) 0           enc_bn1-2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           enc_act1-2[0][0]
# __________________________________________________________________________________________________
# enc_conv2-1 (Conv2D)            (None, 128, 128, 128 131200      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# enc_bn2-1 (BatchNormalization)  (None, 128, 128, 128 512         enc_conv2-1[0][0]
# __________________________________________________________________________________________________
# enc_act2-1 (LeakyReLU)          (None, 128, 128, 128 0           enc_bn2-1[0][0]
# __________________________________________________________________________________________________
# enc_conv2-2 (Conv2D)            (None, 128, 128, 128 262272      enc_act2-1[0][0]
# __________________________________________________________________________________________________
# enc_bn2-2 (BatchNormalization)  (None, 128, 128, 128 512         enc_conv2-2[0][0]
# __________________________________________________________________________________________________
# enc_act2-2 (LeakyReLU)          (None, 128, 128, 128 0           enc_bn2-2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           enc_act2-2[0][0]
# __________________________________________________________________________________________________
# enc_conv3-1 (Conv2D)            (None, 64, 64, 256)  524544      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# enc_bn3-1 (BatchNormalization)  (None, 64, 64, 256)  1024        enc_conv3-1[0][0]
# __________________________________________________________________________________________________
# enc_act3-1 (LeakyReLU)          (None, 64, 64, 256)  0           enc_bn3-1[0][0]
# __________________________________________________________________________________________________
# enc_conv3-2 (Conv2D)            (None, 64, 64, 256)  1048832     enc_act3-1[0][0]
# __________________________________________________________________________________________________
# enc_bn3-2 (BatchNormalization)  (None, 64, 64, 256)  1024        enc_conv3-2[0][0]
# __________________________________________________________________________________________________
# enc_act3-2 (LeakyReLU)          (None, 64, 64, 256)  0           enc_bn3-2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           enc_act3-2[0][0]
# __________________________________________________________________________________________________
# enc_convbtleneck-1 (Conv2D)     (None, 32, 32, 512)  2097664     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# enc_bnbtleneck-1 (BatchNormaliz (None, 32, 32, 512)  2048        enc_convbtleneck-1[0][0]
# __________________________________________________________________________________________________
# enc_actbtleneck-1 (LeakyReLU)   (None, 32, 32, 512)  0           enc_bnbtleneck-1[0][0]
# __________________________________________________________________________________________________
# enc_convbtleneck-2 (Conv2D)     (None, 32, 32, 512)  4194816     enc_actbtleneck-1[0][0]
# __________________________________________________________________________________________________
# enc_bnbtleneck-2 (BatchNormaliz (None, 32, 32, 512)  2048        enc_convbtleneck-2[0][0]
# __________________________________________________________________________________________________
# enc_actbtleneck-2 (LeakyReLU)   (None, 32, 32, 512)  0           enc_bnbtleneck-2[0][0]
# __________________________________________________________________________________________________
# dec_conv0-1 (Conv2D)            (None, 32, 32, 256)  2097408     enc_actbtleneck-2[0][0]
# __________________________________________________________________________________________________
# dec_bn0-1 (BatchNormalization)  (None, 32, 32, 256)  1024        dec_conv0-1[0][0]
# __________________________________________________________________________________________________
# dec_act0-1 (LeakyReLU)          (None, 32, 32, 256)  0           dec_bn0-1[0][0]
# __________________________________________________________________________________________________
# dec_drop0-1 (Dropout)           (None, 32, 32, 256)  0           dec_act0-1[0][0]
# __________________________________________________________________________________________________
# dec_conv0-2 (Conv2DTranspose)   (None, 64, 64, 256)  1048832     dec_drop0-1[0][0]
# __________________________________________________________________________________________________
# dec_bn0-2 (BatchNormalization)  (None, 64, 64, 256)  1024        dec_conv0-2[0][0]
# __________________________________________________________________________________________________
# dec_act0-2 (LeakyReLU)          (None, 64, 64, 256)  0           dec_bn0-2[0][0]
# __________________________________________________________________________________________________
# resize_to_same0 (Lambda)        (None, 64, 64, 256)  0           dec_act0-2[0][0]
#                                                                  enc_act3-2[0][0]
# __________________________________________________________________________________________________
# dec_conc0 (Concatenate)         (None, 64, 64, 512)  0           resize_to_same0[0][0]
#                                                                  enc_act3-2[0][0]
# __________________________________________________________________________________________________
# dec_conv1-1 (Conv2D)            (None, 64, 64, 128)  1048704     dec_conc0[0][0]
# __________________________________________________________________________________________________
# dec_bn1-1 (BatchNormalization)  (None, 64, 64, 128)  512         dec_conv1-1[0][0]
# __________________________________________________________________________________________________
# dec_act1-1 (LeakyReLU)          (None, 64, 64, 128)  0           dec_bn1-1[0][0]
# __________________________________________________________________________________________________
# dec_drop1-1 (Dropout)           (None, 64, 64, 128)  0           dec_act1-1[0][0]
# __________________________________________________________________________________________________
# dec_conv1-2 (Conv2DTranspose)   (None, 128, 128, 128 262272      dec_drop1-1[0][0]
# __________________________________________________________________________________________________
# dec_bn1-2 (BatchNormalization)  (None, 128, 128, 128 512         dec_conv1-2[0][0]
# __________________________________________________________________________________________________
# dec_act1-2 (LeakyReLU)          (None, 128, 128, 128 0           dec_bn1-2[0][0]
# __________________________________________________________________________________________________
# resize_to_same1 (Lambda)        (None, 128, 128, 128 0           dec_act1-2[0][0]
#                                                                  enc_act2-2[0][0]
# __________________________________________________________________________________________________
# dec_conc1 (Concatenate)         (None, 128, 128, 256 0           resize_to_same1[0][0]
#                                                                  enc_act2-2[0][0]
# __________________________________________________________________________________________________
# dec_conv2-1 (Conv2D)            (None, 128, 128, 64) 262208      dec_conc1[0][0]
# __________________________________________________________________________________________________
# dec_bn2-1 (BatchNormalization)  (None, 128, 128, 64) 256         dec_conv2-1[0][0]
# __________________________________________________________________________________________________
# dec_act2-1 (LeakyReLU)          (None, 128, 128, 64) 0           dec_bn2-1[0][0]
# __________________________________________________________________________________________________
# dec_conv2-2 (Conv2DTranspose)   (None, 256, 256, 64) 65600       dec_act2-1[0][0]
# __________________________________________________________________________________________________
# dec_bn2-2 (BatchNormalization)  (None, 256, 256, 64) 256         dec_conv2-2[0][0]
# __________________________________________________________________________________________________
# dec_act2-2 (LeakyReLU)          (None, 256, 256, 64) 0           dec_bn2-2[0][0]
# __________________________________________________________________________________________________
# resize_to_same2 (Lambda)        (None, 256, 256, 64) 0           dec_act2-2[0][0]
#                                                                  enc_act1-2[0][0]
# __________________________________________________________________________________________________
# dec_conc2 (Concatenate)         (None, 256, 256, 128 0           resize_to_same2[0][0]
#                                                                  enc_act1-2[0][0]
# __________________________________________________________________________________________________
# dec_conv3-1 (Conv2D)            (None, 256, 256, 32) 65568       dec_conc2[0][0]
# __________________________________________________________________________________________________
# dec_bn3-1 (BatchNormalization)  (None, 256, 256, 32) 128         dec_conv3-1[0][0]
# __________________________________________________________________________________________________
# dec_act3-1 (LeakyReLU)          (None, 256, 256, 32) 0           dec_bn3-1[0][0]
# __________________________________________________________________________________________________
# dec_conv3-2 (Conv2DTranspose)   (None, 512, 512, 32) 16416       dec_act3-1[0][0]
# __________________________________________________________________________________________________
# dec_bn3-2 (BatchNormalization)  (None, 512, 512, 32) 128         dec_conv3-2[0][0]
# __________________________________________________________________________________________________
# dec_act3-2 (LeakyReLU)          (None, 512, 512, 32) 0           dec_bn3-2[0][0]
# __________________________________________________________________________________________________
# resize_to_same3 (Lambda)        (None, 512, 512, 32) 0           dec_act3-2[0][0]
#                                                                  enc_act0-2[0][0]
# __________________________________________________________________________________________________
# dec_conc3 (Concatenate)         (None, 512, 512, 64) 0           resize_to_same3[0][0]
#                                                                  enc_act0-2[0][0]
# __________________________________________________________________________________________________
# dec_out1 (Conv2D)               (None, 512, 512, 32) 32800       dec_conc3[0][0]
# __________________________________________________________________________________________________
# drop_out1 (Dropout)             (None, 512, 512, 32) 0           dec_out1[0][0]
# __________________________________________________________________________________________________
# dec_out2 (Conv2D)               (None, 512, 512, 32) 16416       drop_out1[0][0]
# __________________________________________________________________________________________________
# drop_out2 (Dropout)             (None, 512, 512, 32) 0           dec_out2[0][0]
# __________________________________________________________________________________________________
# dec_output (Conv2D)             (None, 512, 512, 2)  66          drop_out2[0][0]
# ==================================================================================================
# Total params: 13,303,810
# Trainable params: 13,297,922
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
from custom_loss_metrics import (SegmentationLoss, SegmentationAccuracy, SegmentationMeanIoU, get_mask_for_valid_labels)

# %%
import collections
from keras_custom_callbacks import SimpleLogCallback

# Callback to simply log metrics at the end of each epoch (saving space compared to verbose=1):
metrics_to_print = collections.OrderedDict([("loss", "loss"), ("v-loss", "val_loss"),
                                            ("acc", "acc"), ("v-acc", "val_acc"),
                                            ("mIoU", "mIoU"), ("v-mIoU", "val_mIoU")])

callback_simple_log = SimpleLogCallback(metrics_to_print, num_epochs=num_epochs)

# %%
optimizer = tf.keras.optimizers.Adam()
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=8, monitor='val_loss',
                                    restore_best_weights=True),
    tf.keras.callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True),
    callback_simple_log
]

# %%
unet_model.compile(optimizer=optimizer, loss=SegmentationLoss(from_logits=True), 
                   metrics=[SegmentationAccuracy(), SegmentationMeanIoU(num_classes)])

# %%
unet_model.load_weights('unet_model.h5')

# %%
unet_model.fit(dataset, epochs=num_epochs, steps_per_epoch=tf.math.ceil(5088 / batch_size),
               validation_data=validation, validation_steps = tf.math.ceil(100 / batch_size),
               callbacks=callbacks)
# Out:
# Train for 509.0 steps, validate for 10.0 steps
# Training: start.
# Epoch 1/10
# 508/509 [============================>.] - ETA: 1:04 - loss: 0.0477 - acc: 0.9829 - mIoU: 0.9497Epoch  0/10: loss = 0.048; v-loss = 0.572; acc = 0.983; v-acc = 0.877; mIoU = 0.950; v-mIoU = 0.733
# 509/509 [==============================] - 32763s 64s/step - loss: 0.0477 - acc: 0.9829 - mIoU: 0.9497 - val_loss: 0.5723 - val_acc: 0.8769 - val_mIoU: 0.7329
# Epoch 2/10
# 508/509 [============================>.] - ETA: 1:02 - loss: 0.0327 - acc: 0.9878 - mIoU: 0.9636Epoch  1/10: loss = 0.033; v-loss = 0.109; acc = 0.988; v-acc = 0.952; mIoU = 0.964; v-mIoU = 0.872
# 509/509 [==============================] - 32213s 63s/step - loss: 0.0327 - acc: 0.9878 - mIoU: 0.9636 - val_loss: 0.1086 - val_acc: 0.9525 - val_mIoU: 0.8725
# Epoch 3/10
#   1/509 [..............................] - ETA: 10:39:30WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are:
# Training: end.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in on_epoch(self, epoch, mode)
#     766     try:
# --> 767       yield epoch_logs
#     768     finally:
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-553ef00e1084> in <module>
#       1 unet_model.fit(dataset, epochs=num_epochs, steps_per_epoch=tf.math.ceil(5088 / batch_size),
#       2                validation_data=validation, validation_steps = tf.math.ceil(100 / batch_size),
# ----> 3                callbacks=callbacks)
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# /usr/lib64/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# ~/image_segmentation/keras_custom_callbacks.py in on_epoch_end(self, epoch, logs)
#     101     def on_epoch_end(self, epoch, logs={}):
#     102         if (epoch - 1) % self.log_frequency == 0 or epoch == self.num_epochs:
# --> 103             values = [logs[self.metrics_dict[metric_name]] for metric_name in self.metrics_dict]
#     104             print(self.log_string_template.format(epoch, self.num_epochs, *values))
#     105
#
# ~/image_segmentation/keras_custom_callbacks.py in <listcomp>(.0)
#     101     def on_epoch_end(self, epoch, logs={}):
#     102         if (epoch - 1) % self.log_frequency == 0 or epoch == self.num_epochs:
# --> 103             values = [logs[self.metrics_dict[metric_name]] for metric_name in self.metrics_dict]
#     104             print(self.log_string_template.format(epoch, self.num_epochs, *values))
#     105
#
# KeyError: 'loss'

# %%
unet_model.save('unet_model_ep4.h5')

# %%
prediction = unet_model.predict(next(dataset_train_images.batch(4).__iter__()))

# %%
prediction.shape
# Out:
# (4, 512, 512, 2)

# %%
val1 = prediction[0]

# %%
val1.shape
# Out:
# (512, 512, 2)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(np.argmax(val1, axis=-1),cmap='gray')

# %%
np.argmax(prediction[3], axis=-1).min()
# Out:
# 1
